# %% [markdown]
# AUTHORS:
#
# ASEM HATAMLEH
#
# MUNIS ALAWNEH

# %%
import cv2
import matplotlib.pyplot as plt

cap = cv2.VideoCapture('http://192.168.1.3:8080/video')

if not cap.isOpened():
    print("Cannot open camera")
    exit()
ret, frame = cap.read()

# Check if frame is received
if ret:
    # Convert color from BGR to RGB
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame)
    plt.title('IP Webcam Feed')
    plt.show()
else:
    print("Can't receive frame (stream end?). Exiting ...")

# Release everything if job is finished
cap.release()

# %% [markdown]
# ### Working

# %%
'''
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')  # Ensure the model is on GPU

# Function to apply a basic grayscale night vision effect
def apply_night_vision(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    equalized = cv2.equalizeHist(gray)
    return cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_skip = 3  # Adjust the number of frames to skip if necessary
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        # Convert frame to tensor and send to GPU
        frame_tensor = torch.from_numpy(frame).to('cuda')
        # Apply night vision effect
        night_vision_frame = apply_night_vision(frame_tensor.cpu().numpy())

        # Perform object detection
        results = model(night_vision_frame)
        # Render detections on the frame
        annotated_frame = results[0].plot()
        
        # Display the frame
        cv2.imshow("Night Vision with Object Detection", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows() 
'''
print()

# %% [markdown]
# ### dont change this

# %%
'''
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')  # Ensure the model is on GPU

# Function to apply a basic grayscale night vision effect
def apply_night_vision(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    equalized = cv2.equalizeHist(gray)
    return cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_skip = 3  # Adjust the number of frames to skip if necessary
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        # Convert frame to tensor and send to GPU
        frame_tensor = torch.from_numpy(frame).to('cuda')
        # Apply night vision effect
        night_vision_frame = apply_night_vision(frame_tensor.cpu().numpy())

        # Perform object detection
        results = model(night_vision_frame)
        # Render detections on the frame
        annotated_frame = results[0].plot()

        # Display the frame
        cv2.imshow("Night Vision with Object Detection", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()  
'''
print()

# %% [markdown]
# ## no effect

# %%
'''
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')

# Function to apply grayscale conversion and prepare the image
def prepare_frame(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    bgr = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)
    resized = cv2.resize(bgr, (640, 640))  # Example size
    tensor = torch.from_numpy(resized).float() / 255.0
    tensor = tensor.permute(2, 0, 1).unsqueeze(0).to('cuda')
    return tensor

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Create a window and set it to fullscreen
cv2.namedWindow("Display Window", cv2.WINDOW_NORMAL)
cv2.setWindowProperty("Display Window", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

frame_skip = 3
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        frame_tensor = prepare_frame(frame)
        results = model(frame_tensor)
        annotated_frame = results[0].plot()

        cv2.imshow("Display Window", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows() 
'''
print()

# %% [markdown]
# ### image  negative

# %%
'''
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')  # Ensure the model is on GPU

# Function to apply a basic grayscale night vision effect with negative image
def apply_night_vision_and_negative(frame):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Equalize histogram to improve contrast
    equalized = cv2.equalizeHist(gray)
    # Apply negative effect
    negative = 255 - equalized
    # Convert back to BGR to keep the three channel format
    return cv2.cvtColor(negative, cv2.COLOR_GRAY2BGR)

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_skip = 3  # Adjust the number of frames to skip if necessary
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        # Convert frame to tensor and send to GPU
        frame_tensor = torch.from_numpy(frame).to('cuda')
        # Apply night vision and negative effect
        processed_frame = apply_night_vision_and_negative(frame_tensor.cpu().numpy())

        # Perform object detection
        results = model(processed_frame)
        # Render detections on the frame
        annotated_frame = results[0].plot()

        # Display the frame
        cv2.imshow("Night Vision with Negative Effect and Object Detection", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows() 
'''
print()

# %% [markdown]
# ###  histogram equalization

# %%
'''
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')  # Ensure the model is on GPU

# Function to apply histogram equalization and Gaussian smoothing
def apply_enhancements(frame):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Apply histogram equalization
    equalized = cv2.equalizeHist(gray)
    # Apply Gaussian smoothing
    smoothed = cv2.GaussianBlur(equalized, (5, 5), 0)
    # Convert back to BGR to keep the three channel format
    return cv2.cvtColor(smoothed, cv2.COLOR_GRAY2BGR)

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_skip = 3  # Adjust the number of frames to skip if necessary
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        # Convert frame to tensor and send to GPU
        frame_tensor = torch.from_numpy(frame).to('cuda')
        # Apply enhancements including histogram equalization and smoothing
        processed_frame = apply_enhancements(frame_tensor.cpu().numpy())

        # Perform object detection
        results = model(processed_frame)
        # Render detections on the frame
        annotated_frame = results[0].plot()

        # Display the frame
        cv2.imshow("Enhanced Night Vision with Object Detection", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
'''
print()

# %% [markdown]
# ###  Gaussian smoothing

# %%
'''
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')  # Ensure the model is on GPU

# Function to apply grayscale conversion and Gaussian smoothing
def apply_enhancements(frame):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Apply Gaussian smoothing
    smoothed = cv2.GaussianBlur(gray, (5, 5), 0)
    # Convert back to BGR to keep the three channel format
    return cv2.cvtColor(smoothed, cv2.COLOR_GRAY2BGR)

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_skip = 3  # Adjust the number of frames to skip if necessary
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        # Convert frame to tensor and send to GPU
        frame_tensor = torch.from_numpy(frame).to('cuda')
        # Apply grayscale and Gaussian smoothing
        processed_frame = apply_enhancements(frame_tensor.cpu().numpy())

        # Perform object detection
        results = model(processed_frame)
        # Render detections on the frame
        annotated_frame = results[0].plot()

        # Display the frame
        cv2.imshow("Smoothed Night Vision with Object Detection", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows() 

'''
print()

# %% [markdown]
# ###  gamma

# %%
import cv2
import numpy as np
import torch
from ultralytics import YOLO

# Check if PyTorch can see the GPU
print("CUDA Available:", torch.cuda.is_available())

# Load the YOLOv5 model with GPU support
model = YOLO('yolov5s.pt').to('cuda')  # Ensure the model is on GPU

# Precompute the gamma correction lookup table
def gamma_correction_table(gamma=1):
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255 for i in np.arange(0, 256)]).astype("uint8")
    return table

gamma_table = gamma_correction_table(1.4)

# Function to apply grayscale conversion, Gaussian smoothing, and Gamma transformation using LUT
def apply_enhancements(frame, gamma_table):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Apply Gaussian smoothing
    smoothed = cv2.GaussianBlur(gray, (5, 5), 0)
    # Apply Gamma correction using the lookup table
    gamma_corrected = cv2.LUT(smoothed, gamma_table)
    # Convert back to BGR to keep the three channel format
    return cv2.cvtColor(gamma_corrected, cv2.COLOR_GRAY2BGR)

# Open the webcam
cap = cv2.VideoCapture('http://192.168.1.3:8080/video')
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

frame_skip = 3  # Adjust the number of frames to skip if necessary
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    if frame_count % frame_skip == 0:
        # Convert frame to tensor and send to GPU
        frame_tensor = torch.from_numpy(frame).to('cuda')
        # Apply grayscale, Gaussian smoothing, and Gamma transformation using LUT
        processed_frame = apply_enhancements(frame_tensor.cpu().numpy(), gamma_table)

        # Perform object detection
        results = model(processed_frame)
        # Render detections on the frame
        annotated_frame = results[0].plot()

        # Display the frame
        cv2.imshow("Enhanced Night Vision with Gamma Correction and Object Detection", annotated_frame)

    frame_count += 1

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# '\nimport cv2\nimport numpy as np\nimport torch\nfrom ultralytics import YOLO\n\n# Check if PyTorch can see the GPU\nprint("CUDA Available:", torch.cuda.is_available())\n\n# Load the YOLOv5 model with GPU support\nmodel = YOLO(\'yolov5s.pt\').to(\'cuda\')  # Ensure the model is on GPU\n\n# Precompute the gamma correction lookup table\ndef gamma_correction_table(gamma=1):\n    invGamma = 1.0 / gamma\n    table = np.array([((i / 255.0) ** invGamma) * 255 for i in np.arange(0, 256)]).astype("uint8")\n    return table\n\ngamma_table = gamma_correction_table(1.4)\n\n# Function to apply grayscale conversion, Gaussian smoothing, and Gamma transformation using LUT\ndef apply_enhancements(frame, gamma_table):\n    # Convert to grayscale\n    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)\n    # Apply Gaussian smoothing\n    smoothed = cv2.GaussianBlur(gray, (5, 5), 0)\n    # Apply Gamma correction using the lookup table\n    gamma_corrected = cv2.LUT(smoothed, gamma_table)\n    # Convert back
# ...
